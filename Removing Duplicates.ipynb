# %%
import pandas as pd
data={'marks':[1,1,2,2,3,3],
              'test1':[15,16,2,2,5,16]}
data1=pd.DataFrame(data)

# %%
data1
# Out:
#    marks  test1
# 0      1     15
# 1      1     16
# 2      2      2
# 3      2      2
# 4      3      5
# 5      3     16

# %%
data1.duplicated(data)
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5    False
# dtype: bool

# %%
data1.drop_duplicates()
# Out:
#    marks  test1
# 0      1     15
# 1      1     16
# 2      2      2
# 4      3      5
# 5      3     16

# %%
data1.drop_duplicates('test1')
# Out:
#    marks  test1
# 0      1     15
# 1      1     16
# 2      2      2
# 4      3      5

# %%
import pandas as pd
df=pd.read_csv("school1.csv")

# %%
df
# Out:
#         UNITID     OPEID  OPEID6  \
# 0       100654    100200    1002
# 1       100663    105200    1052
# 2       100690   2503400   25034
# 3       100706    105500    1055
# 4       100724    100500    1005
# 5       100751    105100    1051
# 6       100760    100700    1007
# 7       100812    100800    1008
# 8       100830    831000    8310
# 9       100858    100900    1009
# 10      100937    101200    1012
# 11      101028   1218200   12182
# 12      101073   1055400   10554
# 13      101116   1303906   13039
# 14      101143    101500    1015
# 15      101161    106000    1060
# 16      101189    100300    1003
# 17      101240    101700    1017
# 18      101277   4187200   41872
# 19      101286    101800    1018
# 20      101295    787100    7871
# 21      101301    569900    5699
# 22      101365    962107    9621
# 23      101435    101900    1019
# 24      101453   2199700   21997
# 25      101462    526000    5260
# 26      101480    102000    1020
# ...

# %%
df.index=df['UNITID']

# %%
df
# Out:
#             UNITID     OPEID  OPEID6  \
# UNITID
# 100654      100654    100200    1002
# 100663      100663    105200    1052
# 100690      100690   2503400   25034
# 100706      100706    105500    1055
# 100724      100724    100500    1005
# 100751      100751    105100    1051
# 100760      100760    100700    1007
# 100812      100812    100800    1008
# 100830      100830    831000    8310
# 100858      100858    100900    1009
# 100937      100937    101200    1012
# 101028      101028   1218200   12182
# 101073      101073   1055400   10554
# 101116      101116   1303906   13039
# 101143      101143    101500    1015
# 101161      101161    106000    1060
# 101189      101189    100300    1003
# 101240      101240    101700    1017
# 101277      101277   4187200   41872
# 101286      101286    101800    1018
# 101295      101295    787100    7871
# 101301      101301    569900    5699
# 101365      101365    962107    9621
# 101435      101435    101900    1019
# ...

# %%
ipl=pd.read_csv("Ball_by_Ball.csv")

# %%
ipl
# Out:
#         Match_Id  Innings_Id  Over_Id  Ball_Id  Team_Batting_Id  \
# 0         335987           1        1        1                1
# 1         335987           1        1        2                1
# 2         335987           1        1        3                1
# 3         335987           1        1        4                1
# 4         335987           1        1        5                1
# 5         335987           1        1        6                1
# 6         335987           1        1        7                1
# 7         335987           1        2        1                1
# 8         335987           1        2        2                1
# 9         335987           1        2        3                1
# 10        335987           1        2        4                1
# 11        335987           1        2        5                1
# 12        335987           1        2        6                1
# 13        335987           1        3        1                1
# ...
